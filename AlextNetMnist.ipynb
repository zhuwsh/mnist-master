# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# load数据
# import input_data
# mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
mnist = input_data.read_data_sets('data/', one_hot=True)

# 定义网络超参数
learning_rate = 0.001
training_iters = 200000
batch_size = 64
display_step = 20

# 定义网络参数
n_input = 784 # 输入的维度
n_classes = 10 # 标签的维度
dropout = 0.8 # Dropout 的概率

# 占位符输入
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32)

# 卷积操作
def conv2d(name, l_input, w, b):
    return tf.nn.relu(tf.nn.bias_add(tf.nn.conv2d(l_input, w, strides=[1, 1, 1, 1], padding='SAME'),b), name=name)

# 最大下采样操作
def max_pool(name, l_input, k):
    return tf.nn.max_pool(l_input, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME', name=name)

# 归一化操作
def norm(name, l_input, lsize=4):
    return tf.nn.lrn(l_input, lsize, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name=name)

# 定义整个网络 
def alex_net(_X, _weights, _biases, _dropout):
    # 向量转为矩阵
    _X = tf.reshape(_X, shape=[-1, 28, 28, 1])

    # 卷积层
    conv1 = conv2d('conv1', _X, _weights['wc1'], _biases['bc1'])
    # 下采样层
    pool1 = max_pool('pool1', conv1, k=2)
    # 归一化层
    norm1 = norm('norm1', pool1, lsize=4)
    # Dropout
    norm1 = tf.nn.dropout(norm1, _dropout)

    # 卷积
    conv2 = conv2d('conv2', norm1, _weights['wc2'], _biases['bc2'])
    # 下采样
    pool2 = max_pool('pool2', conv2, k=2)
    # 归一化
    norm2 = norm('norm2', pool2, lsize=4)
    # Dropout
    norm2 = tf.nn.dropout(norm2, _dropout)

    # 卷积
    conv3 = conv2d('conv3', norm2, _weights['wc3'], _biases['bc3'])
    # 下采样
    pool3 = max_pool('pool3', conv3, k=2)
    # 归一化
    norm3 = norm('norm3', pool3, lsize=4)
    # Dropout
    norm3 = tf.nn.dropout(norm3, _dropout)

    # 全连接层，先把特征图转为向量
    dense1 = tf.reshape(norm3, [-1, _weights['wd1'].get_shape().as_list()[0]]) 
    dense1 = tf.nn.relu(tf.matmul(dense1, _weights['wd1']) + _biases['bd1'], name='fc1') 
    # 全连接层
    dense2 = tf.nn.relu(tf.matmul(dense1, _weights['wd2']) + _biases['bd2'], name='fc2') # Relu activation

    # 网络输出层
    out = tf.matmul(dense2, _weights['out']) + _biases['out']
    return out

# 存储所有的网络参数
weights = {
    'wc1': tf.Variable(tf.random_normal([3, 3, 1, 64])),
    'wc2': tf.Variable(tf.random_normal([3, 3, 64, 128])),
    'wc3': tf.Variable(tf.random_normal([3, 3, 128, 256])),
    'wd1': tf.Variable(tf.random_normal([4*4*256, 1024])),
    'wd2': tf.Variable(tf.random_normal([1024, 1024])),
    'out': tf.Variable(tf.random_normal([1024, 10]))
}
biases = {
    'bc1': tf.Variable(tf.random_normal([64])),
    'bc2': tf.Variable(tf.random_normal([128])),
    'bc3': tf.Variable(tf.random_normal([256])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'bd2': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# 构建模型
pred = alex_net(x, weights, biases, keep_prob)

# 定义损失函数和学习步骤
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# 测试网络
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# 初始化所有的共享变量
init = tf.initialize_all_variables()

# 开启一个训练
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        # 获取批数据
        sess.run(optimizer, feed_dict={x: batch_xs, y: batch_ys, keep_prob: dropout})
        if step % display_step == 0:
            # 计算精度
            acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
            # 计算损失值
            loss = sess.run(cost, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
            print ("Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc))
        step += 1
    print ("Optimization Finished!")
    # 计算测试精度
    print ("Testing Accuracy:", sess.run(accuracy, feed_dict={x: mnist.test.images[:256], y: mnist.test.labels[:256], keep_prob: 1.}))
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From D:\software_installed\Anaconda\lib\site-packages\tensorflow\python\util\tf_should_use.py:189: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Iter 1280, Minibatch Loss= 108938.421875, Training Accuracy= 0.26562
# Iter 2560, Minibatch Loss= 73678.390625, Training Accuracy= 0.31250
# Iter 3840, Minibatch Loss= 51186.152344, Training Accuracy= 0.53125
# Iter 5120, Minibatch Loss= 38684.578125, Training Accuracy= 0.56250
# Iter 6400, Minibatch Loss= 46353.976562, Training Accuracy= 0.62500
# Iter 7680, Minibatch Loss= 40819.945312, Training Accuracy= 0.64062
# Iter 8960, Minibatch Loss= 34133.601562, Training Accuracy= 0.60938
# Iter 10240, Minibatch Loss= 37105.011719, Training Accuracy= 0.59375
# Iter 11520, Minibatch Loss= 20689.500000, Training Accuracy= 0.64062
# Iter 12800, Minibatch Loss= 19490.800781, Training Accuracy= 0.70312
# Iter 14080, Minibatch Loss= 19457.945312, Training Accuracy= 0.71875
# Iter 15360, Minibatch Loss= 32874.906250, Training Accuracy= 0.67188
# Iter 16640, Minibatch Loss= 19544.042969, Training Accuracy= 0.73438
# Iter 17920, Minibatch Loss= 24515.126953, Training Accuracy= 0.73438
# Iter 19200, Minibatch Loss= 9274.566406, Training Accuracy= 0.82812
# Iter 20480, Minibatch Loss= 16745.367188, Training Accuracy= 0.75000
# Iter 21760, Minibatch Loss= 16241.908203, Training Accuracy= 0.84375
# Iter 23040, Minibatch Loss= 8159.422852, Training Accuracy= 0.78125
# Iter 24320, Minibatch Loss= 13151.234375, Training Accuracy= 0.76562
# Iter 25600, Minibatch Loss= 21003.976562, Training Accuracy= 0.73438
# Iter 26880, Minibatch Loss= 13163.576172, Training Accuracy= 0.75000
# Iter 28160, Minibatch Loss= 17401.437500, Training Accuracy= 0.75000
# Iter 29440, Minibatch Loss= 10859.864258, Training Accuracy= 0.75000
# Iter 30720, Minibatch Loss= 8340.238281, Training Accuracy= 0.82812
# Iter 32000, Minibatch Loss= 12808.156250, Training Accuracy= 0.75000
# Iter 33280, Minibatch Loss= 17219.873047, Training Accuracy= 0.78125
# Iter 34560, Minibatch Loss= 8939.807617, Training Accuracy= 0.85938
# Iter 35840, Minibatch Loss= 9589.253906, Training Accuracy= 0.81250
# Iter 37120, Minibatch Loss= 8495.150391, Training Accuracy= 0.76562
# Iter 38400, Minibatch Loss= 5696.802734, Training Accuracy= 0.90625
# Iter 39680, Minibatch Loss= 8146.381348, Training Accuracy= 0.85938
# Iter 40960, Minibatch Loss= 5138.713379, Training Accuracy= 0.87500
# Iter 42240, Minibatch Loss= 6092.337402, Training Accuracy= 0.82812
# Iter 43520, Minibatch Loss= 6600.463379, Training Accuracy= 0.84375
# Iter 44800, Minibatch Loss= 7659.929688, Training Accuracy= 0.85938
# Iter 46080, Minibatch Loss= 10835.078125, Training Accuracy= 0.79688
# Iter 47360, Minibatch Loss= 6091.684082, Training Accuracy= 0.89062
# Iter 48640, Minibatch Loss= 10448.284180, Training Accuracy= 0.76562
# Iter 49920, Minibatch Loss= 5032.968262, Training Accuracy= 0.85938
# Iter 51200, Minibatch Loss= 6718.521973, Training Accuracy= 0.87500
# Iter 52480, Minibatch Loss= 11233.337891, Training Accuracy= 0.78125
# Iter 53760, Minibatch Loss= 5578.796387, Training Accuracy= 0.85938
# Iter 55040, Minibatch Loss= 12712.009766, Training Accuracy= 0.78125
# Iter 56320, Minibatch Loss= 12371.164062, Training Accuracy= 0.75000
# Iter 57600, Minibatch Loss= 3695.938721, Training Accuracy= 0.89062
# Iter 58880, Minibatch Loss= 6058.905273, Training Accuracy= 0.89062
# Iter 60160, Minibatch Loss= 3198.329102, Training Accuracy= 0.89062
# Iter 61440, Minibatch Loss= 7564.524902, Training Accuracy= 0.84375
# Iter 62720, Minibatch Loss= 9627.014648, Training Accuracy= 0.81250
# Iter 64000, Minibatch Loss= 5285.828125, Training Accuracy= 0.82812
# Iter 65280, Minibatch Loss= 6696.502930, Training Accuracy= 0.81250
# Iter 66560, Minibatch Loss= 6095.748047, Training Accuracy= 0.84375
# Iter 67840, Minibatch Loss= 2592.431152, Training Accuracy= 0.89062
# Iter 69120, Minibatch Loss= 4695.037598, Training Accuracy= 0.92188
# Iter 70400, Minibatch Loss= 6473.708008, Training Accuracy= 0.78125
# Iter 71680, Minibatch Loss= 7041.678711, Training Accuracy= 0.85938
# Iter 72960, Minibatch Loss= 5507.446289, Training Accuracy= 0.84375
# Iter 74240, Minibatch Loss= 7132.177734, Training Accuracy= 0.85938
# Iter 75520, Minibatch Loss= 10986.723633, Training Accuracy= 0.82812
# Iter 76800, Minibatch Loss= 9899.121094, Training Accuracy= 0.84375
# Iter 78080, Minibatch Loss= 4316.936035, Training Accuracy= 0.92188
# Iter 79360, Minibatch Loss= 3495.933838, Training Accuracy= 0.93750
# Iter 80640, Minibatch Loss= 8609.403320, Training Accuracy= 0.87500
# Iter 81920, Minibatch Loss= 3113.643311, Training Accuracy= 0.89062
# Iter 83200, Minibatch Loss= 4192.925293, Training Accuracy= 0.92188
# Iter 84480, Minibatch Loss= 3971.755127, Training Accuracy= 0.89062
# Iter 85760, Minibatch Loss= 8897.554688, Training Accuracy= 0.79688
# Iter 87040, Minibatch Loss= 6088.501953, Training Accuracy= 0.78125
# Iter 88320, Minibatch Loss= 8651.236328, Training Accuracy= 0.79688
# Iter 89600, Minibatch Loss= 7127.220703, Training Accuracy= 0.82812
# Iter 90880, Minibatch Loss= 3594.917725, Training Accuracy= 0.84375
# Iter 92160, Minibatch Loss= 1348.529663, Training Accuracy= 0.92188
# Iter 93440, Minibatch Loss= 413.185913, Training Accuracy= 0.98438
# Iter 94720, Minibatch Loss= 2856.891113, Training Accuracy= 0.90625
# Iter 96000, Minibatch Loss= 3081.936279, Training Accuracy= 0.89062
# Iter 97280, Minibatch Loss= 4301.821289, Training Accuracy= 0.90625
# Iter 98560, Minibatch Loss= 1275.213867, Training Accuracy= 0.92188
# Iter 99840, Minibatch Loss= 4339.038086, Training Accuracy= 0.87500
# Iter 101120, Minibatch Loss= 3337.558594, Training Accuracy= 0.89062
# Iter 102400, Minibatch Loss= 3115.135254, Training Accuracy= 0.89062
# Iter 103680, Minibatch Loss= 1417.779663, Training Accuracy= 0.89062
# Iter 104960, Minibatch Loss= 4775.295898, Training Accuracy= 0.85938
# Iter 106240, Minibatch Loss= 3737.499268, Training Accuracy= 0.87500
# Iter 107520, Minibatch Loss= 5163.098145, Training Accuracy= 0.82812
# Iter 108800, Minibatch Loss= 4631.295898, Training Accuracy= 0.84375
# Iter 110080, Minibatch Loss= 2645.987305, Training Accuracy= 0.92188
# Iter 111360, Minibatch Loss= 4491.318359, Training Accuracy= 0.90625
# Iter 112640, Minibatch Loss= 1767.472900, Training Accuracy= 0.93750
# Iter 113920, Minibatch Loss= 3005.246094, Training Accuracy= 0.87500
# Iter 115200, Minibatch Loss= 1255.028809, Training Accuracy= 0.93750
# Iter 116480, Minibatch Loss= 1625.587646, Training Accuracy= 0.89062
# Iter 117760, Minibatch Loss= 1001.190979, Training Accuracy= 0.90625
# Iter 119040, Minibatch Loss= 2734.257080, Training Accuracy= 0.90625
# Iter 120320, Minibatch Loss= 1514.894775, Training Accuracy= 0.95312
# Iter 121600, Minibatch Loss= 3710.089844, Training Accuracy= 0.89062
# Iter 122880, Minibatch Loss= 3237.234131, Training Accuracy= 0.85938
# Iter 124160, Minibatch Loss= 555.247192, Training Accuracy= 0.93750
# Iter 125440, Minibatch Loss= 2952.141113, Training Accuracy= 0.87500
# Iter 126720, Minibatch Loss= 5854.169922, Training Accuracy= 0.85938
# Iter 128000, Minibatch Loss= 424.825012, Training Accuracy= 0.96875
# Iter 129280, Minibatch Loss= 1425.425537, Training Accuracy= 0.93750
# Iter 130560, Minibatch Loss= 3004.906250, Training Accuracy= 0.89062
# Iter 131840, Minibatch Loss= 3182.503906, Training Accuracy= 0.93750
# Iter 133120, Minibatch Loss= 355.961426, Training Accuracy= 0.95312
# Iter 134400, Minibatch Loss= 358.805542, Training Accuracy= 0.95312
# Iter 135680, Minibatch Loss= 4736.462891, Training Accuracy= 0.90625
# Iter 136960, Minibatch Loss= 5363.991211, Training Accuracy= 0.90625
# Iter 138240, Minibatch Loss= 1941.423340, Training Accuracy= 0.90625
# Iter 139520, Minibatch Loss= 3871.509521, Training Accuracy= 0.89062
# Iter 140800, Minibatch Loss= 3795.385498, Training Accuracy= 0.89062
# Iter 142080, Minibatch Loss= 3108.583984, Training Accuracy= 0.89062
# Iter 143360, Minibatch Loss= 1307.599854, Training Accuracy= 0.92188
# Iter 144640, Minibatch Loss= 2208.587646, Training Accuracy= 0.90625
# Iter 145920, Minibatch Loss= 3185.951660, Training Accuracy= 0.92188
# Iter 147200, Minibatch Loss= 415.601959, Training Accuracy= 0.96875
# Iter 148480, Minibatch Loss= 576.575378, Training Accuracy= 0.93750
# Iter 149760, Minibatch Loss= 3422.324463, Training Accuracy= 0.85938
# Iter 151040, Minibatch Loss= 159.138855, Training Accuracy= 0.95312
# Iter 152320, Minibatch Loss= 2796.022705, Training Accuracy= 0.92188
# Iter 153600, Minibatch Loss= 2302.508301, Training Accuracy= 0.90625
# Iter 154880, Minibatch Loss= 2953.690430, Training Accuracy= 0.87500
# Iter 156160, Minibatch Loss= 14.646362, Training Accuracy= 0.98438
# Iter 157440, Minibatch Loss= 1023.785950, Training Accuracy= 0.95312
# Iter 158720, Minibatch Loss= 2650.244141, Training Accuracy= 0.90625
# Iter 160000, Minibatch Loss= 1328.910889, Training Accuracy= 0.95312
# Iter 161280, Minibatch Loss= 1895.878418, Training Accuracy= 0.92188
# Iter 162560, Minibatch Loss= 862.216248, Training Accuracy= 0.93750
# Iter 163840, Minibatch Loss= 1008.871033, Training Accuracy= 0.95312
# Iter 165120, Minibatch Loss= 1176.916504, Training Accuracy= 0.95312
# Iter 166400, Minibatch Loss= 1278.360107, Training Accuracy= 0.93750
# Iter 167680, Minibatch Loss= 5682.708008, Training Accuracy= 0.87500
# Iter 168960, Minibatch Loss= 2077.154541, Training Accuracy= 0.92188
# Iter 170240, Minibatch Loss= 1465.967407, Training Accuracy= 0.87500
# Iter 171520, Minibatch Loss= 1159.114014, Training Accuracy= 0.95312
# Iter 172800, Minibatch Loss= 2218.439453, Training Accuracy= 0.93750
# Iter 174080, Minibatch Loss= 2478.305176, Training Accuracy= 0.92188
# Iter 175360, Minibatch Loss= 3090.584717, Training Accuracy= 0.89062
# Iter 176640, Minibatch Loss= 1051.243896, Training Accuracy= 0.92188
# Iter 177920, Minibatch Loss= 780.951538, Training Accuracy= 0.95312
# Iter 179200, Minibatch Loss= 950.172485, Training Accuracy= 0.93750
# Iter 180480, Minibatch Loss= 370.688538, Training Accuracy= 0.96875
# Iter 181760, Minibatch Loss= 643.121948, Training Accuracy= 0.95312
# Iter 183040, Minibatch Loss= 729.722900, Training Accuracy= 0.93750
# Iter 184320, Minibatch Loss= 2165.395996, Training Accuracy= 0.93750
# Iter 185600, Minibatch Loss= 685.328369, Training Accuracy= 0.98438
# Iter 186880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 188160, Minibatch Loss= 911.033447, Training Accuracy= 0.93750
# Iter 189440, Minibatch Loss= 2174.477539, Training Accuracy= 0.87500
# Iter 190720, Minibatch Loss= 679.670715, Training Accuracy= 0.95312
# Iter 192000, Minibatch Loss= 490.828613, Training Accuracy= 0.95312
# Iter 193280, Minibatch Loss= 1268.356567, Training Accuracy= 0.90625
# Iter 194560, Minibatch Loss= 1577.673950, Training Accuracy= 0.92188
# Iter 195840, Minibatch Loss= 3038.138916, Training Accuracy= 0.90625
# Iter 197120, Minibatch Loss= 542.683716, Training Accuracy= 0.98438
# Iter 198400, Minibatch Loss= 597.439026, Training Accuracy= 0.90625
# Iter 199680, Minibatch Loss= 926.953979, Training Accuracy= 0.92188
# Optimization Finished!
# Testing Accuracy: 0.9453125
